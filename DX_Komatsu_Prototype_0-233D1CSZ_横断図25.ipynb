# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/mnt/c/Users/CINPC0075/Desktop/Repo-KCIN3D-reconstruction/Demo1_233D1CSZ_横断図25.csv',index_col=0)
df.head()
# Out:
#       Name  Author Closed  Color  Comments  Drawing Revision Number  \
# Count
# 1      Arc     NaN    NaN  white       NaN                      NaN
# 1      Arc     NaN    NaN  white       NaN                      NaN
# 1      Arc     NaN    NaN  white       NaN                      NaN
# 1      Arc     NaN    NaN  white       NaN                      NaN
# 1      Arc     NaN    NaN  white       NaN                      NaN
#
#        EdgeStyleId  FaceStyleId     File Accessed      File Created  ...  \
# Count                                                                ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
#
# ...

# %%
df.info()
print('----------------------------------',
     "---------------------------------------",
     '-------------------------------------')
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 983 entries, 1 to 9
# Data columns (total 72 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     983 non-null    object
#  1   Author                   0 non-null      float64
#  2   Closed                   47 non-null     object
#  3   Color                    983 non-null    object
#  4   Comments                 0 non-null      float64
#  5   Drawing Revision Number  0 non-null      float64
#  6   EdgeStyleId              983 non-null    int64
#  7   FaceStyleId              983 non-null    int64
#  8   File Accessed            983 non-null    object
#  9   File Created             983 non-null    object
#  10  File Last Saved By       983 non-null    object
#  11  File Location            983 non-null    object
#  12  File Modified            983 non-null    object
#  13  File Name                983 non-null    object
# ...

# %%
to_drop = ['Author','Closed', 'Comments', 'Drawing Revision Number', 'EdgeStyleId', 'FaceStyleId', 'File Accessed', 'File Created', 'File Last Saved By', 'File Location',
...            'File Modified','File Name', 'File Size', 'Fit Smooth', 'Hyperlink', 'Hyperlink Base', 'Keywords']

df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#       Name  Color       Layer  Length    Linetype  Linetype Scale Lineweight  \
# Count
# 1      Arc  white  D-STR-STRB  0.0107  Continuous               1    0.25 mm
# 1      Arc  white  D-STR-STRB  0.0107  Continuous               1    0.25 mm
# 1      Arc  white  D-STR-STRB  0.0158  Continuous               1    0.25 mm
# 1      Arc  white  D-STR-STRB  0.0158  Continuous               1    0.25 mm
# 1      Arc  white  D-STR-STRB  0.0208  Continuous               1    0.25 mm
#
#       Material Plot Style  Subject  ...  TextDefinedSize  Height  Obliquing  \
# Count                               ...
# 1      ByLayer    Color_7      NaN  ...              NaN     NaN        NaN
# 1      ByLayer    Color_7      NaN  ...              NaN     NaN        NaN
# 1      ByLayer    Color_7      NaN  ...              NaN     NaN        NaN
# 1      ByLayer    Color_7      NaN  ...              NaN     NaN        NaN
# 1      ByLayer    Color_7      NaN  ...              NaN     NaN        NaN
# ...

# %%
ar = df.loc[df["Name"] == "Arc"]
ar.loc[:,["Center X"]]
# Out:
#        Center X
# Count
# 1       93.6857
# 1       93.6857
# 1       93.7053
# 1       93.6781
# 1       93.8254
# ...         ...
# 1      100.9455
# 1      100.7579
# 1       62.2062
# 1       62.3938
# 1       54.7868
#
# [410 rows x 1 columns]

# %%
lm = df.loc[df["Name"]== "Line"]
lm
# Out:
#        Name  Color       Layer  Length    Linetype  Linetype Scale Lineweight  \
# Count
# 1      Line  white  D-STR-STRB  0.5405  Continuous               1    0.25 mm
# 1      Line  white  D-STR-STRB  0.5405  Continuous               1    0.25 mm
# 1      Line  white  D-STR-STRB  0.1833  Continuous               1    0.25 mm
# 1      Line  white  D-STR-STRB  0.3500  Continuous               1    0.25 mm
# 1      Line  white  D-STR-STRB  0.0300  Continuous               1    0.25 mm
# ...     ...    ...         ...     ...         ...             ...        ...
# 1      Line  white   D-STR-DIM  2.8006  Continuous               1    0.13 mm
# 2      Line    red       D-STR  0.8065  Continuous               1    0.40 mm
# 2      Line    red       D-STR  0.8065  Continuous               1    0.40 mm
# 2      Line    red       D-STR  0.8065  Continuous               1    0.40 mm
# 2      Line    red       D-STR  0.8065  Continuous               1    0.40 mm
#
# ...

# %%
llm1 = lm.loc[lm["End X"]==lm["Start X"]]
llm1
# Out:
#        Name  Color       Layer   Length    Linetype  Linetype Scale  \
# Count
# 1      Line  white  D-STR-STRB   0.0300  Continuous               1
# 1      Line  white  D-STR-STRB   0.0300  Continuous               1
# 1      Line  white  D-TTL-LINE   1.9303  Continuous               1
# 1      Line  white  D-TTL-LINE   1.9303  Continuous               1
# 1      Line  white  D-TTL-LINE  11.5819  Continuous               1
# ...     ...    ...         ...      ...         ...             ...
# 1      Line  white  D-STR-STRB   0.0300  Continuous               1
# 1      Line  white  D-STR-STRB   0.1000  Continuous               1
# 1      Line  white  D-STR-STRB   0.0300  Continuous               1
# 1      Line  white  D-STR-STRB   0.0300  Continuous               1
# 1      Line  white  D-STR-STRB   0.0300  Continuous               1
#
#       Lineweight Material Plot Style  Subject  ...  TextDefinedSize  Height  \
# Count                                          ...
# ...

# %%
for xi in ar["Center X"]:
    for xii in llm1["End X"]:
        if xi == xii:
            print(xi)
# Out:
# 89.1
# 89.1
# 89.1
# 89.1
# 89.1
# 89.1
# 89.1
# 89.1

# %%
lm = df.loc[df["Name"]== "Line"]
lq = lm.loc[lm["Color"]=="red"]
lq.head
# Out:
# <bound method NDFrame.head of        Name Color       Layer  Length    Linetype  Linetype Scale Lineweight  \
# Count
# 1      Line   red       D-STR  0.1562  Continuous               1    0.40 mm
# 1      Line   red  D-STR-STRB  0.0938  Continuous               1    0.25 mm
# 1      Line   red  D-STR-STRB  0.3000  Continuous               1    0.25 mm
# 1      Line   red       D-STR  0.5507  Continuous               1    0.40 mm
# 1      Line   red       D-STR  0.1380  Continuous               1    0.40 mm
# ...     ...   ...         ...     ...         ...             ...        ...
# 1      Line   red  D-STR-STRB  0.0938  Continuous               1    0.25 mm
# 2      Line   red       D-STR  0.8065  Continuous               1    0.40 mm
# 2      Line   red       D-STR  0.8065  Continuous               1    0.40 mm
# 2      Line   red       D-STR  0.8065  Continuous               1    0.40 mm
# 2      Line   red       D-STR  0.8065  Continuous               1    0.40 mm
#
# ...

# %%
lq.loc[:, ["End X", "End Y", "End Z", "Start X", "Start Y", "Start Z"]]
# Out:
#          End X    End Y  End Z  Start X  Start Y  Start Z
# Count
# 1      61.4517  43.5733    0.0  61.6079  43.5733      0.0
# 1      62.3000  43.0655    0.0  62.2062  43.0655      0.0
# 1      62.4500  43.0255    0.0  62.1500  43.0255      0.0
# 1      53.1000  50.3681    0.0  52.5500  50.3406      0.0
# 1      53.2000  50.2730    0.0  53.1000  50.3681      0.0
# ...        ...      ...    ...      ...      ...      ...
# 1      62.3938  98.4655    0.0  62.3000  98.4655      0.0
# 2      94.9225  84.7903    0.0  94.1200  84.7100      0.0
# 2      83.2775  84.7903    0.0  84.0800  84.7100      0.0
# 2      94.9225  29.3903    0.0  94.1200  29.3100      0.0
# 2      83.2775  29.3903    0.0  84.0800  29.3100      0.0
#
# [210 rows x 6 columns]

# %%
#for 3D polyline 1
lq.sort_values(by= 'Start X', ascending=False)
lq.loc[:,["End X", "End Y", "End Z", "Start X", "Start Y", "Start Z"]]
# Out:
#          End X    End Y  End Z  Start X  Start Y  Start Z
# Count
# 1      61.4517  43.5733    0.0  61.6079  43.5733      0.0
# 1      62.3000  43.0655    0.0  62.2062  43.0655      0.0
# 1      62.4500  43.0255    0.0  62.1500  43.0255      0.0
# 1      53.1000  50.3681    0.0  52.5500  50.3406      0.0
# 1      53.2000  50.2730    0.0  53.1000  50.3681      0.0
# ...        ...      ...    ...      ...      ...      ...
# 1      62.3938  98.4655    0.0  62.3000  98.4655      0.0
# 2      94.9225  84.7903    0.0  94.1200  84.7100      0.0
# 2      83.2775  84.7903    0.0  84.0800  84.7100      0.0
# 2      94.9225  29.3903    0.0  94.1200  29.3100      0.0
# 2      83.2775  29.3903    0.0  84.0800  29.3100      0.0
#
# [210 rows x 6 columns]

# %%
#for 3D polyline 2
lq.sort_values(by= 'End X', ascending=False)
lq.loc[:,["End X", "End Y", "End Z", "Start X", "Start Y", "Start Z"]]
# Out:
#          End X    End Y  End Z  Start X  Start Y  Start Z
# Count
# 1      61.4517  43.5733    0.0  61.6079  43.5733      0.0
# 1      62.3000  43.0655    0.0  62.2062  43.0655      0.0
# 1      62.4500  43.0255    0.0  62.1500  43.0255      0.0
# 1      53.1000  50.3681    0.0  52.5500  50.3406      0.0
# 1      53.2000  50.2730    0.0  53.1000  50.3681      0.0
# ...        ...      ...    ...      ...      ...      ...
# 1      62.3938  98.4655    0.0  62.3000  98.4655      0.0
# 2      94.9225  84.7903    0.0  94.1200  84.7100      0.0
# 2      83.2775  84.7903    0.0  84.0800  84.7100      0.0
# 2      94.9225  29.3903    0.0  94.1200  29.3100      0.0
# 2      83.2775  29.3903    0.0  84.0800  29.3100      0.0
#
# [210 rows x 6 columns]

# %%
#for 3D polyline half the road right
lqhalfR = lq.loc[lq["End X"]>= 89.1]
lqhalfR.sort_values(by= 'End X', ascending=False)
lqhalfR.loc[:, ["End X", "End Y", "End Z", "Start X", "Start Y", "Start Z"]]
# Out:
#           End X    End Y  End Z   Start X  Start Y  Start Z
# Count
# 1      109.9846  40.5368    0.0  105.0000  36.3830      0.0
# 1      104.6336  36.2015    0.0  104.6500  36.3655      0.0
# 1      104.6500  36.3655    0.0  104.6900  36.3655      0.0
# 1      104.6900  36.3355    0.0  104.6900  36.3655      0.0
# 1      104.5000  36.1255    0.0  104.3500  36.1255      0.0
# 1      104.4062  36.1655    0.0  104.5000  36.1655      0.0
# 1      104.6500  36.4656    0.0  104.9616  36.4812      0.0
# 1      105.1921  36.6733    0.0  104.9616  36.4812      0.0
# 1      104.6500  36.3655    0.0  105.0000  36.3830      0.0
# 1      104.3500  36.3655    0.0  103.5000  36.4080      0.0
# 1      103.8000  36.4931    0.0  104.3500  36.4656      0.0
# 1      103.7000  36.3980    0.0  103.8000  36.4931      0.0
# 1      104.6500  36.4656    0.0  104.6500  36.3655      0.0
# 1      104.3500  36.4656    0.0  104.3500  36.3655      0.0
# 1       95.1000  29.4080    0.0   94.1200  29.3100      0.0
# ...

# %%
#for 3D polyline half the road left
lqhalfL = lq.loc[lq["End X"]< 89.1]
lqhalfL.sort_values(by= 'End X', ascending=False)
lqhalfL.loc[:, ["End X", "End Y", "End Z", "Start X", "Start Y", "Start Z"]]
# Out:
#          End X    End Y  End Z  Start X  Start Y  Start Z
# Count
# 1      61.4517  43.5733    0.0  61.6079  43.5733      0.0
# 1      62.3000  43.0655    0.0  62.2062  43.0655      0.0
# 1      62.4500  43.0255    0.0  62.1500  43.0255      0.0
# 1      53.1000  50.3681    0.0  52.5500  50.3406      0.0
# 1      53.2000  50.2730    0.0  53.1000  50.3681      0.0
# ...        ...      ...    ...      ...      ...      ...
# 1      62.1500  98.6655    0.0  62.1100  98.6655      0.0
# 1      62.4751  98.4506    0.0  62.4500  98.4255      0.0
# 1      62.3938  98.4655    0.0  62.3000  98.4655      0.0
# 2      83.2775  84.7903    0.0  84.0800  84.7100      0.0
# 2      83.2775  29.3903    0.0  84.0800  29.3100      0.0
#
# [175 rows x 6 columns]

# %%
lq2DE = lq[["End X","End Y","End Z"]]
lq2DS = lq[["Start X","Start Y","Start Z"]]

# %%
coordinates = pd.concat([lq2DE,lq2DS], axis=1)
coordinates.reset_index(drop=True)
# Out:
#        End X    End Y  End Z  Start X  Start Y  Start Z
# 0    61.4517  43.5733    0.0  61.6079  43.5733      0.0
# 1    62.3000  43.0655    0.0  62.2062  43.0655      0.0
# 2    62.4500  43.0255    0.0  62.1500  43.0255      0.0
# 3    53.1000  50.3681    0.0  52.5500  50.3406      0.0
# 4    53.2000  50.2730    0.0  53.1000  50.3681      0.0
# ..       ...      ...    ...      ...      ...      ...
# 205  62.3938  98.4655    0.0  62.3000  98.4655      0.0
# 206  94.9225  84.7903    0.0  94.1200  84.7100      0.0
# 207  83.2775  84.7903    0.0  84.0800  84.7100      0.0
# 208  94.9225  29.3903    0.0  94.1200  29.3100      0.0
# 209  83.2775  29.3903    0.0  84.0800  29.3100      0.0
#
# [210 rows x 6 columns]

# %%
coordinates.to_csv('/mnt/c/Users/CINPC0075/Desktop/Repo-KCIN3D-reconstruction/Demo1_OUT1_233D1CSZ_横断図25.csv',index=False, header=False)
