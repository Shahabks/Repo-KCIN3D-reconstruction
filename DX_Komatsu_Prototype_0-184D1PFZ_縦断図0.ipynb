# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/mnt/c/Users/CINPC0075/Desktop/Komatsu/Client_DWGs/Demo-up-FS/Demo1_184D1PFZ_縦断図0.csv',index_col=0)
df.head()
# Out:
#        Name  Author Closed  Color  Comments  Drawing Revision Number  \
# Count
# 1      Line     NaN    NaN  white       NaN                      NaN
# 1      Line     NaN    NaN  white       NaN                      NaN
# 1      Line     NaN    NaN  white       NaN                      NaN
# 1      Line     NaN    NaN  white       NaN                      NaN
# 1      Line     NaN    NaN  white       NaN                      NaN
#
#        EdgeStyleId  FaceStyleId     File Accessed      File Created  ...  \
# Count                                                                ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
# 1                0            0  05/03/2021 08:58  05/03/2021 08:58  ...
#
# ...

# %%
df.info()
print('----------------------------------',
     "---------------------------------------",
     '-------------------------------------')
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1150 entries, 1 to 9
# Data columns (total 81 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     1150 non-null   object
#  1   Author                   0 non-null      float64
#  2   Closed                   14 non-null     object
#  3   Color                    1150 non-null   object
#  4   Comments                 0 non-null      float64
#  5   Drawing Revision Number  0 non-null      float64
#  6   EdgeStyleId              1150 non-null   int64
#  7   FaceStyleId              1150 non-null   int64
#  8   File Accessed            1150 non-null   object
#  9   File Created             1150 non-null   object
#  10  File Last Saved By       1150 non-null   object
#  11  File Location            1150 non-null   object
#  12  File Modified            1150 non-null   object
#  13  File Name                1150 non-null   object
# ...

# %%
to_drop = ['Author','Closed', 'Comments', 'Drawing Revision Number', 'EdgeStyleId', 'FaceStyleId', 'File Accessed', 'File Created', 'File Last Saved By', 'File Location',
...            'File Modified','File Name', 'File Size', 'Fit Smooth', 'Hyperlink', 'Hyperlink Base', 'Keywords']

df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#        Name  Color       Layer    Length    Linetype  Linetype Scale  \
# Count
# 1      Line  white  D-TTL-BAND    2.0000  Continuous               1
# 1      Line  white  D-TTL-BAND    2.0000  Continuous               1
# 1      Line  white  D-TTL-BAND  627.2178  Continuous               1
# 1      Line  white  D-TTL-BAND    2.0000  Continuous               1
# 1      Line  white  D-TTL-BAND    2.0000  Continuous               1
#
#       Lineweight Material Plot Style  Subject  ...  TextDefinedSize  Height  \
# Count                                          ...
# 1        0.13 mm  ByLayer    Color_7      NaN  ...              NaN     NaN
# 1        0.13 mm  ByLayer    Color_7      NaN  ...              NaN     NaN
# 1        0.13 mm  ByLayer    Color_7      NaN  ...              NaN     NaN
# 1        0.13 mm  ByLayer    Color_7      NaN  ...              NaN     NaN
# 1        0.13 mm  ByLayer    Color_7      NaN  ...              NaN     NaN
#
# ...

# %%
df.set_index("Value",inplace= True)
df
# Out:
#               Name  Color       Layer    Length    Linetype  Linetype Scale  \
# Value
# NaN           Line  white  D-TTL-BAND    2.0000  Continuous               1
# NaN           Line  white  D-TTL-BAND    2.0000  Continuous               1
# NaN           Line  white  D-TTL-BAND  627.2178  Continuous               1
# NaN           Line  white  D-TTL-BAND    2.0000  Continuous               1
# NaN           Line  white  D-TTL-BAND    2.0000  Continuous               1
# ...            ...    ...         ...       ...         ...             ...
# NaN           Line  white   D-STR-TXT   43.7500  Continuous               1
# NaN           Line  white   D-STR-TXT   30.0000  Continuous               1
# NaN           Line  white   D-STR-TXT   38.9474  Continuous               1
# NaN    3D Polyline  white  D-STR-HTXT   26.1803  Continuous               1
# NaN    3D Polyline  white  D-TTL-BAND   60.0000  Continuous               1
#
# ...

# %%
df.loc[["高", "計","画"], ["Position X", "Position Y", "Position Z"]]
# Out:
#        Position X  Position Y  Position Z
# Value
# 高         75.8862     146.509         0.0
# 高         75.8862     190.509         0.0
# 高         75.8862     212.509         0.0
# 高         75.8862     168.509         0.0
# 計         75.8862     155.509         0.0
# 画         75.8862     162.009         0.0

# %%
lm = df.loc[df["Position Y"]>155]
lq = lm.loc[lm["Position Y"]<169]
lq.head
# Out:
# <bound method NDFrame.head of          Name  Color       Layer  Length    Linetype  Linetype Scale  \
# Value
# 高        Text  white   D-TTL-TXT     NaN  Continuous               1
# 計        Text  white   D-TTL-TXT     NaN  Continuous               1
# 画        Text  white   D-TTL-TXT     NaN  Continuous               1
# 528.431  Text  white  D-TTL-BAND     NaN  Continuous               1
# 527.85   Text  white  D-TTL-BAND     NaN  Continuous               1
# 529.65   Text  white  D-TTL-BAND     NaN  Continuous               1
# 529.05   Text  white  D-TTL-BAND     NaN  Continuous               1
# 524.25   Text  white  D-TTL-BAND     NaN  Continuous               1
# 523.05   Text  white  D-TTL-BAND     NaN  Continuous               1
# 526.65   Text  white  D-TTL-BAND     NaN  Continuous               1
# 525.45   Text  white  D-TTL-BAND     NaN  Continuous               1
# 530.25   Text  white  D-TTL-BAND     NaN  Continuous               1
# ...

# %%
lz = lq.loc[:,["Position X","Position Y","Position Z"]]
lz.head
# Out:
# <bound method NDFrame.head of          Position X  Position Y  Position Z
# Value
# 高           75.8862    168.5090         0.0
# 計           75.8862    155.5090         0.0
# 画           75.8862    162.0090         0.0
# 528.431    448.8708    162.5104         0.0
# 527.85     458.5500    162.5104         0.0
# 529.65     428.5500    162.5104         0.0
# 529.05     438.5500    162.5104         0.0
# 524.25     518.5500    162.5104         0.0
# 523.05     538.5500    162.5104         0.0
# 526.65     478.5500    162.5104         0.0
# 525.45     498.5500    162.5104         0.0
# 530.25     418.5500    162.5104         0.0
# 536.25     318.5500    162.5104         0.0
# 535.05     338.5500    162.5104         0.0
# 537.158    302.0500    162.5104         0.0
# 537.158    305.5500    162.5104         0.0
# 531.75     393.5500    162.5104         0.0
# 531.45     398.5500    162.5104         0.0
# 533.85     358.5500    162.5104         0.0
# ...

# %%
df.loc[["DL=500.000"], ["Position X", "Position Y", "Position Z"]]
# Out:
#             Position X  Position Y  Position Z
# Value
# DL=500.000      65.002    245.4335         0.0

# %%
lla = df.loc[df["Name"]=="Line"]
llb = lla.loc[lla["Start Y"]>244]
llc = llb.loc[llb["Start Y"]<245.5]
lld = llc.loc[llc["Start X"]>60]
lle = lld.loc[lld["Start X"]<100]
llf = lle.loc[:,["Name","Start X", "Start Y", "Start Z"]]
llf.head
# Out:
# <bound method NDFrame.head of        Name  Start X  Start Y  Start Z
# Value
# NaN    Line  80.0000  245.009      0.0
# NaN    Line  80.0000  245.009      0.0
# NaN    Line  80.0000  245.009      0.0
# NaN    Line  97.4751  245.009      0.0>

# %%
llg = lz.iloc[3:].astype(int)
llg.head
# Out:
# <bound method NDFrame.head of          Position X  Position Y  Position Z
# Value
# 528.431         448         162           0
# 527.85          458         162           0
# 529.65          428         162           0
# 529.05          438         162           0
# 524.25          518         162           0
# 523.05          538         162           0
# 526.65          478         162           0
# 525.45          498         162           0
# 530.25          418         162           0
# 536.25          318         162           0
# 535.05          338         162           0
# 537.158         302         162           0
# 537.158         305         162           0
# 531.75          393         162           0
# 531.45          398         162           0
# 533.85          358         162           0
# 532.65          378         162           0
# 522.33          550         162           0
# 516.686         687         162           0
# ...

# %%
llh = llg.reset_index()
llh["Value"] = pd.to_numeric(llh["Value"], downcast="float")
llh["Position X"] = pd.to_numeric(llh["Position X"], downcast="float")
llhh = llh.sort_values(by="Value", ascending=False) 
scale = 245.009/500
print(scale)
llhh.head
# Out:
# 0.49001799999999995
# <bound method NDFrame.head of          Value  Position X  Position Y  Position Z
# 39  547.849976        98.0         162           0
# 40  546.849976       118.0         162           0
# 38  545.849976       138.0         162           0
# 32  544.849976       158.0         162           0
# 33  543.849976       178.0         162           0
# 30  542.849976       198.0         162           0
# 31  542.815002       202.0         162           0
# 36  541.849976       218.0         162           0
# 37  540.848022       238.0         162           0
# 34  539.788025       258.0         162           0
# 35  538.648010       278.0         162           0
# 29  537.450012       298.0         162           0
# 11  537.158020       302.0         162           0
# 12  537.158020       305.0         162           0
# 9   536.250000       318.0         162           0
# 10  535.049988       338.0         162           0
# ...

# %%
lli = (llhh["Value"]-500)*scale*10
lli.head
# Out:
# <bound method NDFrame.head of 39    234.473495
# 40    229.573334
# 38    224.673141
# 32    219.772949
# 33    214.872772
# 30    209.972595
# 31    209.801208
# 36    205.072418
# 37    200.162659
# 34    194.968491
# 35    189.382202
# 29    183.511810
# 11    182.080994
# 12    182.080994
# 9     177.631531
# 10    171.751251
# 15    165.870972
# 16    159.990997
# 13    155.580719
# 14    154.110733
# 8     148.230453
# 2     145.290466
# 3     142.350174
# 0     139.317169
# 1     136.469894
# 6     130.589920
# 7     124.709641
# 4     118.829361
# 5     112.949097
# 17    109.421112
# 23    107.068817
# 24    101.188843
# 21     95.308563
# 22     90.898285
# 27     89.487213
# 28     84.988701
# 25     82.827820
# 19     82.504204
# 26     82.337616
# 18     81.764282
# 20     81.524414
# Name: Value, dtype: float32>

# %%
llj = llhh[["Position X","Position Z"]]
llj.head
# Out:
# <bound method NDFrame.head of     Position X  Position Z
# 39        98.0           0
# 40       118.0           0
# 38       138.0           0
# 32       158.0           0
# 33       178.0           0
# 30       198.0           0
# 31       202.0           0
# 36       218.0           0
# 37       238.0           0
# 34       258.0           0
# 35       278.0           0
# 29       298.0           0
# 11       302.0           0
# 12       305.0           0
# 9        318.0           0
# 10       338.0           0
# 15       358.0           0
# 16       378.0           0
# 13       393.0           0
# 14       398.0           0
# 8        418.0           0
# 2        428.0           0
# 3        438.0           0
# 0        448.0           0
# 1        458.0           0
# 6        478.0           0
# 7        498.0           0
# 4        518.0           0
# 5        538.0           0
# 17       550.0           0
# 23       558.0           0
# 24       578.0           0
# ...

# %%
coordinates = pd.concat([lli,llj], axis=1)
coordinates.reset_index(drop=True)
# Out:
#          Value  Position X  Position Z
# 0   234.473495        98.0           0
# 1   229.573334       118.0           0
# 2   224.673141       138.0           0
# 3   219.772949       158.0           0
# 4   214.872772       178.0           0
# 5   209.972595       198.0           0
# 6   209.801208       202.0           0
# 7   205.072418       218.0           0
# 8   200.162659       238.0           0
# 9   194.968491       258.0           0
# 10  189.382202       278.0           0
# 11  183.511810       298.0           0
# 12  182.080994       302.0           0
# 13  182.080994       305.0           0
# 14  177.631531       318.0           0
# 15  171.751251       338.0           0
# 16  165.870972       358.0           0
# 17  159.990997       378.0           0
# 18  155.580719       393.0           0
# 19  154.110733       398.0           0
# 20  148.230453       418.0           0
# 21  145.290466       428.0           0
# 22  142.350174       438.0           0
# ...

# %%
coordinates.to_csv('/mnt/c/Users/CINPC0075/Desktop/Komatsu/Client_DWGs/Demo-up-FS/Demo1_out_184D1PFZ_縦断図0.csv',index=False, header=False)
